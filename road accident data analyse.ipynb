# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
road_acc_data=pd.read_csv(r"C:\Users\Admin\Desktop\data analyst\s-37 data set\jupiter woking data set\04)RTA Dataset.csv")
road_acc_data
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3      01:06:00      Sunday              18-30          Male
# 4      01:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
road_acc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
#find all the null values
road_acc_data.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
road_acc_data.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
road_acc_data.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
#df.drop(df.columns[[0, 4, 2]], axis=1, inplace=True)

# %%
road_acc_data.drop(columns=["Educational_level", "Vehicle_driver_relation","Defect_of_vehicle","Work_of_casuality","Fitness_of_casuality"], inplace=True)

# %%
road_acc_data
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3      01:06:00      Sunday              18-30          Male
# 4      01:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0                  1-2yr           Automobile            Owner
# 1             Above 10yr  Public (> 45 seats)            Owner
# ...

# %%
road_acc_data.shape
# Out:
# (12316, 27)

# %%
sns.heatmap(road_acc_data.isnull())
plt.show()

# %%
road_acc_data.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Pedestrian_movement               0
# Cause_of_accident                 0
# ...

# %%
#DataFrame.drop_duplicates()
non_duplicate_road_acc_data =road_acc_data .drop_duplicates(keep='first')

# %%
#no dupicate rows found
non_duplicate_road_acc_data
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3      01:06:00      Sunday              18-30          Male
# 4      01:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0                  1-2yr           Automobile            Owner
# 1             Above 10yr  Public (> 45 seats)            Owner
# ...

# %%
# remove the nan and see the row count

# %%
non_duplicate_road_acc_data.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
#        'Service_year_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
columns=['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
       'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
       'Service_year_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
       'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
       'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
       'Type_of_collision', 'Number_of_vehicles_involved',
       'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
       'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
       'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity']
non_duplicate_road_acc_data.dropna(subset=columns,inplace=True)

# %%
#dataset reduced to 50%
non_duplicate_road_acc_data.shape
# Out:
# (6122, 27)

# %%
non_duplicate_road_acc_data.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# Pedestrian_movement            object
# ...

# %%
non_duplicate_road_acc_data["Type_of_vehicle"].replace({"Public (> 45 seats)":"bus","Automobile":"car","Lorry (41?100Q)":"truck","Public (13?45 seats)":"bus","Long lorry":"truck","Lorry (11?40Q)":"truck","Taxi":"car","Pick up upto 10Q":"truck","Public (12 seats)":"bus","Stationwagen":"car","Ridden horse":"Other","Bajaj":"bike","turbo":"truck","Motorcycle":"bike","Bicycle":"cycle"},inplace=True)
#changing the type in  power bi

# %%
non_duplicate_road_acc_data
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1      17:02:00      Monday              31-50          Male
# 7      17:20:00      Friday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# 10     14:40:00    Saturday              18-30          Male
# ...         ...         ...                ...           ...
# 12306  17:10:00      Friday              18-30          Male
# 12307  17:10:00      Friday              31-50          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Driving_experience Type_of_vehicle Owner_of_vehicle  \
# 1             Above 10yr             bus            Owner
# 7                  2-5yr             car     Governmental
# ...

# %%
non_duplicate_road_acc_data["Type_of_vehicle"].unique()
# Out:
# array(['bus', 'car', 'truck', 'Other', 'bike', 'Turbo', 'Special vehicle',
#        'cycle'], dtype=object)

# %%
non_duplicate_road_acc_data.to_excel("road_accident_dataset_type_of vehicle_clusterd.xlsx",index=False)

# %%
numeric_columns =road_acc_data .select_dtypes(include=['number'])

# Calculate the correlation matrix
corr = numeric_columns.corr()

# Create a heatmap
plt.figure(figsize=(9, 6), dpi=100)
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()
#
